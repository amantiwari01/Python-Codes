# %%
import matplotlib .pyplot as plt
import pandas as pd

# %%
x = [1,2,3]

# %%
y=[4,5,6]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
# pyplot API

# %%
data = {
    "Salary" : [25000,40000,35000,46000,29000,21000,30000,49000,50000,34700,68400,23654,30480,45678]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Salary
# 0    25000
# 1    40000
# 2    35000
# 3    46000
# 4    29000
# 5    21000
# 6    30000
# 7    49000
# 8    50000
# 9    34700
# 10   68400
# 11   23654
# 12   30480
# 13   45678

# %%
df.shape
# Out:
# (14, 1)

# %%
# Line Plot

# %%
plt.plot(df["Salary"],color="Red",marker = "o",linestyle = ":",linewidth = "2")
plt.grid
plt.show()

# %%
plt.hist(df["Salary"], bins = 5,color = "green")
# Out:
# (array([5., 3., 4., 1., 1.]),
#  array([21000., 30480., 39960., 49440., 58920., 68400.]),
#  <BarContainer object of 5 artists>)

# %%
# box plot

# %%
plt.boxplot(df["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e58849090>,
#   <matplotlib.lines.Line2D at 0x13e588491d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x13e58849310>,
#   <matplotlib.lines.Line2D at 0x13e58849450>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13e58848f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e58849590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e588496d0>],
#  'means': []}

# %%
df.loc[10] =[0]

# %%
plt.boxplot(df["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e5a991090>,
#   <matplotlib.lines.Line2D at 0x13e5a990f50>],
#  'caps': [<matplotlib.lines.Line2D at 0x13e5a990e10>,
#   <matplotlib.lines.Line2D at 0x13e5a991450>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13e5a9911d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e5a991a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e5a991950>],
#  'means': []}

# %%
# df.drop(index =10, inplace=True)

# %%
df.shape
# Out:
# (14, 1)

# %%
df["dept"] = ["HR" ,"IT" ,"FINANCE" ,"HR", "HR" ,"FINANCE", "IT"] * 2

# %%
df.head()
# Out:
#    Salary     dept
# 0   25000       HR
# 1   40000       IT
# 2   35000  FINANCE
# 3   46000       HR
# 4   29000       HR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  14 non-null     int64
#  1   dept    14 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 356.0+ bytes

# %%
#  pie Chart
count = df["dept"].value_counts()
count
# Out:
# dept
# HR         6
# IT         4
# FINANCE    4
# Name: count, dtype: int64

# %%
plt.pie(count, labels = count.index, autopct= "%1.0f",explode=[0,0.1,0.2])
plt.axis("equal")
plt.show()

# %%
# count plot
plt.bar(count.index , count,color=["orange","blue","green"])
# Out:
# <BarContainer object of 3 artists>

# %%
df["Age"]= [23,25,29,24,30,35,21,36,38,25,40,31,29,27]

# %%
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       HR   23
# 1   40000       IT   25
# 2   35000  FINANCE   29
# 3   46000       HR   24
# 4   29000       HR   30

# %%
plt.scatter(df["Age"],df["Salary"],color = "orange")

# %%
# line plot
sort_age = df.sort_values("Age")
sort_salary = df.sort_values("Salary")

# %%
# line plot
plt.plot(sort_age["Age"],df["Salary"],color="Red",marker = "o",linestyle = ":",linewidth = "2")

# %%
# bar chat
plt.bar(df["Age"],df["Salary"],color="Red")
# Out:
# <BarContainer object of 14 artists>

# %%
# Bivariation Numerical -categorical

# %%
hr_sal = df[df["dept"] == "HR"]["Salary"]
hr_sal
# Out:
# 0     25000
# 3     46000
# 4     29000
# 7     49000
# 10        0
# 11    23654
# Name: Salary, dtype: int64

# %%
it_sal = df[df["dept"] == "IT"]["Salary"]
it_sal
# Out:
# 1     40000
# 6     30000
# 8     50000
# 13    45678
# Name: Salary, dtype: int64

# %%
finance_sal = df[df["dept"] == "FINANCE"]["Salary"]
finance_sal
# Out:
# 2     35000
# 5     21000
# 9     34700
# 12    30480
# Name: Salary, dtype: int64

# %%
# Boxplot : 

plt.boxplot([hr_sal,it_sal,finance_sal],labels = ["HR","IT","FINANCE"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7036\1047251307.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([hr_sal,it_sal,finance_sal],labels = ["HR","IT","FINANCE"])
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e587cd950>,
#   <matplotlib.lines.Line2D at 0x13e587cda90>,
#   <matplotlib.lines.Line2D at 0x13e587cd6d0>,
#   <matplotlib.lines.Line2D at 0x13e587cd090>,
#   <matplotlib.lines.Line2D at 0x13e5ab80190>,
#   <matplotlib.lines.Line2D at 0x13e5ab802d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x13e587cee90>,
#   <matplotlib.lines.Line2D at 0x13e587cefd0>,
#   <matplotlib.lines.Line2D at 0x13e587cd310>,
#   <matplotlib.lines.Line2D at 0x13e587cd1d0>,
#   <matplotlib.lines.Line2D at 0x13e5ab80410>,
#   <matplotlib.lines.Line2D at 0x13e5ab80550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13e587ce210>,
#   <matplotlib.lines.Line2D at 0x13e587cdd10>,
#   <matplotlib.lines.Line2D at 0x13e5ab80050>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e587cf110>,
#   <matplotlib.lines.Line2D at 0x13e5ab4fd90>,
#   <matplotlib.lines.Line2D at 0x13e5ab80690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e587cf250>,
#   <matplotlib.lines.Line2D at 0x13e5ab4fed0>,
#   <matplotlib.lines.Line2D at 0x13e5ab807d0>],
#  'means': []}

# %%
# pie chart
salary_by_dept =df.groupby("dept")["Salary"].sum()
salary_by_dept
# Out:
# dept
# FINANCE    121180
# HR         172654
# IT         165678
# Name: Salary, dtype: int64

# %%
plt.pie(salary_by_dept, labels = salary_by_dept.index, autopct = "%1.2f", shadow = True, explode = [0.1, 0, 0.1])
plt.axis("equal")
plt.show()

# %%
# bar4 plot

hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
finance_mean = sum(finance_sal)/len(finance_sal)

# %%
plt.bar(["HR", "IT", "Finance"], [hr_mean, it_mean, finance_mean], color = ["green", "black", "red"])
plt.grid()
plt.show()

# %%
# Multivariate Analysis: 3 numerical columns

# %%
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       HR   23
# 1   40000       IT   25
# 2   35000  FINANCE   29
# 3   46000       HR   24
# 4   29000       HR   30

# %%
df["experience"] =  [1, 2, 4, 1.5, 5, 8, 12, 10, 4, 1, 1.2, 2, 3, 1.8]

# %%
df.head()
# Out:
#    Salary     dept  Age  experience
# 0   25000       HR   23         1.0
# 1   40000       IT   25         2.0
# 2   35000  FINANCE   29         4.0
# 3   46000       HR   24         1.5
# 4   29000       HR   30         5.0

# %%
# Bubble PLot:

plt.scatter(df["Age"], df["Salary"], s = df["experience"]*50, color = "skyblue", edgecolors= "black")
plt.title("Age vs Salary vs Experience")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %%
# 2 numerical and 1 categorical column:

# %%
plt.scatter(df["Age"], df["Salary"], c = df["dept"].map({"HR": "yellow", "IT":"blue", "FINANCE": "orange"}))
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Age vs Salary vs Dept")
plt.legend()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7036\3372819946.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
color = {"HR": "yellow", "IT":"blue", "FINANCE": "orange"}

for dept, color in color.items():
    df_dept = df[df["dept"] == dept]
    plt.scatter(df_dept["Age"], df_dept["Salary"], c = color, label = dept)

plt.legend()

# %%
              # Object Oriented API

# %%
fig, axs = plt.subplots(1,3, figsize = (15,5))

# Line plot

axs[0].plot(sort_age["Age"], df["Salary"], color = "red", marker = "*", linewidth = "2", markersize = 2)
axs[0].grid()
axs[0].set_title("Line Plot")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Salary")

# histogram:

axs[1].hist(df["Salary"], bins = 5, color = "skyblue")
axs[1].set_title("Histogram")
axs[1].set_xlabel("Salary")
axs[1].set_ylabel("Frequency")


# Boxplot:

axs[2].boxplot(df["Salary"])
axs[2].set_title("Boxplot")
axs[2].set_xlabel("Salary")

plt.savefig("multipleplots.png")
plt.show()

# %%
data2 = {
    'Year': [2020, 2021, 2022, 2023],
    'Sales': [100, 150, 200, 250],
    'Profit': [20, 30, 40, 50],
    'Expenses': [80, 120, 160, 200]
}

# %%
df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#    Year  Sales  Profit  Expenses
# 0  2020    100      20        80
# 1  2021    150      30       120
# 2  2022    200      40       160
# 3  2023    250      50       200

# %%
plt.plot(df2["Year"], df2["Sales"], label = "Sales")
plt.plot(df2["Year"], df2["Profit"], label = "Profit")
plt.plot(df2["Year"], df2["Expenses"], label = "Expenses")

plt.title("Financial Analysis")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %%
# 3-D Plot:

# %%
ax = plt.axes(projection = "3d")

ax.scatter(df["Age"], df["Salary"], df["experience"])
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_zlabel("Experience")
plt.show()

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(df, x='Age', y='Salary', z='experience', title='3D Scatter Plot')
